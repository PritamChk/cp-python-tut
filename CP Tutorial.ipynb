# %% [markdown]
# # Competitive Coding Basics
# #### CP Language : Python
# ##### Pritam Chakraborty
# ---
# > - Setup For Coding
# > - I/O Format
# > - Time Complexity
# > - Online Resources
# > - Important Inbuilt libraries to Know

# %% [markdown]
# # Setup for Coding
# ---
# > - Sublime Text
# > - VS Code
# > - Jupyter Notebook

# %% [markdown]
# ## Sublime Text
# ---
# > - install sublime
#     - [Download Link](https://www.sublimetext.com/)
#
#
# > - install plugin for Autosave
#
#
# > - create 3 group
#     - Coding Section
#     - Input Section
#     - Output Section

# %% [markdown]
# ## VS CODE
# ---
# > Step 1:
#     ---
#     > - Install Chrome Extension -> Competitive Companion
#     > - Install VS Code Pluging -> Competitive Coding
#
# ---
# > Step 2:
#     ---
#     > - Goto CP Qus in Chrome Browser
#     > - Press the Competitive Companion (+) button
#     > - Open VS Code.
#     > - It will show a drop down for Coding Lang, Choose Python

# %% [markdown]
# ## Jupyter Notebook (This is totally optional)
# ---
# > Install it for running small snippets

# %% [markdown]
# # I/O Types
# ---
# > Test Cases
# ---
# ![image.png](attachment:image.png)
# ---
#
# > Code Syntax
# ```python
# for _ in range(int(input())):
#     pass
# ```

# %%
for _  in range(int(input())):
    print(f'Test Case #{_ + 1}: Yo')
# Out:
# 9
# Test Case #1: Yo
# Test Case #2: Yo
# Test Case #3: Yo
# Test Case #4: Yo
# Test Case #5: Yo
# Test Case #6: Yo
# Test Case #7: Yo
# Test Case #8: Yo
# Test Case #9: Yo

# %% [markdown]
# ### Discuss About map function
# >
#     map()
#     class map(object)
#     |  map(func, *iterables) --> map object

# %%
## show examples here

# %% [markdown]
# ## Output
# ----
# > as the output will be too large so print the output as follows
#
# > Ans % ( $ 10^9 + 7 $ )
#
# ---
# ![image.png](attachment:image.png)

# %%
## Code Goes here

# %% [markdown]
# # Time Complexity
# ---
#
# >  Points to be remembered :
#
#   >  Online Judges like Codechef, Codeforces, Top Coder, Spoj etc processes
#   > $10^9$ operations per sec
#
#   > So if you are given 1 sec Time Limit for a Problem
#   > then your algo should perform at most $10^9$ operations (approx.)
#
# ----
# ## Time Complexity Calculation
# ---
# ![image.png](attachment:image.png)
#
# ----
# > How to Calculate Time Complexity :
#
# [![Yt Vdo](https://i.ytimg.com/an_webp/M0tgJaQAo60/mqdefault_6s.webp?du=3000&sqp=CLXqt4UG&rs=AOn4CLA_CDmVqg5DD5eh3iawek61Xjv6rw)](https://www.youtube.com/watch?v=M0tgJaQAo60)
#
# ---
# > - TLE
# > - RE
# > - MLE
# etc
# [![Common Verdicts in CP](https://i.ytimg.com/vi/BMc9hB4hvXU/hqdefault.jpg?sqp=-oaymwEbCKgBEF5IVfKriqkDDggBFQAAiEIYAXABwAEG&rs=AOn4CLA2lI9Cdw8NlpRmXpBBW9JhXr-Vdg)](https://youtu.be/BMc9hB4hvXU)

# %% [markdown]
# # Online Resources
# ---
# > ### Online Judges :
#
# > - [**Codechef**](https://www.codechef.com/)
# > - [**CodeForces**](https://codeforces.com/)
# > - [**SPOJ**](https://www.spoj.com/)
#
# ---
# > ### Algorithms
#  > - [**GeekForGeeks**](https://www.geeksforgeeks.org/)
#  > - [**CP-Algorithms**](https://cp-algorithms.com/)
#
#  ---
# > ### Python Libraries to Know
# > - math
# > - collections
# > - itertools
# > - heap
# > - deque
# > - bisect
#
# > [Article On above topic](https://www.geeksforgeeks.org/which-python-modules-are-useful-for-competitive-programming/)
